# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# reward10 = np.load('./data/data_result/reward_{}.npy'.format(10))
# plt.plot(reward10)
# plt.show()

# %%
def np_move_avg(a,n,mode="same"):
    return(np.convolve(a, np.ones((n,))/n, mode=mode))

# %%
cost3 = np.load('./data/data_result/cost_{}.npy'.format(3))
cost10 = np.load('./data/data_result/cost_{}.npy'.format(10))
cost9 = np.load('./data/data_result/cost_{}.npy'.format(9))
Step = np.mean([len(cost3),len(cost10),len(cost9)])
plt.figure()
mode = 'valid'
step = 28
cost3 = cost3[::step]
cost10 = cost10[::step]
cost9 = cost9[::step]
# '#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'
color1, color2, color3 ='#1f77b4', '#ff7f0e', '#2ca02c'
# color1, color2, color3 ='#9467bd', '#ff7f0e', '#1f77b4'
plt.plot(np.linspace(0,Step,len(cost3)),cost3,alpha=1,c=color1,label='Beijing')
# plt.plot(np.linspace(0,Step,len(np_move_avg(cost3,10, mode))),np_move_avg(cost3,10, mode),c= color1)
plt.plot(np.linspace(0,Step,len(cost10)),cost10,alpha=1,c=color2,label='Guangzhou')
# plt.plot(np.linspace(0,Step,len(np_move_avg(cost10,10, mode))),np_move_avg(cost10,10, mode),c=color2)
plt.plot(np.linspace(0,Step,len(cost9)),cost9,alpha=1,c=color3,label='Manhattan')
# plt.plot(np.linspace(0,Step,len(np_move_avg(cost9,10, mode))),np_move_avg(cost9,10, mode),c=color3)
fontsize = 16
plt.legend(fontsize=12)
plt.xticks(fontsize=fontsize,fontfamily='Times New Roman')
plt.yticks(fontsize=fontsize,fontfamily='Times New Roman')
plt.xlabel('Step',fontsize=fontsize,fontfamily='Times New Roman')
plt.ylabel('Loss',fontsize=fontsize,fontfamily='Times New Roman')
# plt.fill_between(smooth_x, smooth_y,alpha=0.2,color='r')
# plt.savefig('F:/yuan/journal/ridesharing_TKDE/figures/loss.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
reward3 = np.load('./data/data_result/reward_{}.npy'.format(3))
reward10 = np.load('./data/data_result/reward_{}.npy'.format(10))
reward9 = np.load('./data/data_result/reward_{}.npy'.format(9))
Episode = np.mean([len(reward3),len(reward10),len(reward9)])
plt.figure()
mode = 'valid'
step = 4
reward3 = reward3[::step]
reward10 = reward10[::3]
reward9 = reward9[::step]
# '#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'
color1, color2, color3 ='#1f77b4', '#ff7f0e', '#2ca02c'
n = 50
plt.plot(np.linspace(0,Episode,len(reward3)),reward3,alpha=0.3,c=color1,linewidth=1)
plt.plot(np.linspace(0,Episode,len(np_move_avg(reward3,n, mode))),np_move_avg(reward3,n, mode),c=color1,label='Beijing')
plt.scatter(np.linspace(0,Episode,len(np_move_avg(reward3,n, mode)[::50])),np_move_avg(reward3,n, mode)[::50],c=color1,marker='o')
plt.plot(np.linspace(0,Episode,len(reward10)),reward10,alpha=0.3,c=color2,linewidth=1)
plt.plot(np.linspace(0,Episode,len(np_move_avg(reward10,n, mode))),np_move_avg(reward10,n, mode),c=color2,label='Guangzhou')
plt.plot(np.linspace(0,Episode,len(reward9)),reward9,alpha=0.3,c=color3,linewidth=1)
plt.plot(np.linspace(0,Episode,len(np_move_avg(reward9,n, mode))),np_move_avg(reward9,n, mode),c=color3,label='Manhattan')
fontsize = 16
plt.legend(fontsize=12)
plt.xticks(fontsize=fontsize,fontfamily='Times New Roman')
plt.yticks(fontsize=fontsize,fontfamily='Times New Roman')
plt.xlabel('Episode',fontsize=fontsize,fontfamily='Times New Roman')
plt.ylabel('Reward',fontsize=fontsize,fontfamily='Times New Roman')
# plt.fill_between(smooth_x, smooth_y,alpha=0.2,color='r')
# plt.savefig('F:/yuan/journal/ridesharing_TKDE/figures/reward.png',dpi=300,bbox_inches='tight')
plt.show()
